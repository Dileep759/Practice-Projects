# %% [markdown]
# ## 1) Read the data and perform basic analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('1.1ML_Exploration_Dataset.csv')

# %%
pd.set_option("display.max_columns", 62)

# %%
df.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# ...

# %%
## dataset shape 
print(f"{'shape of the dataset'.title()} :- {df.shape}")

## duplicate values
print(f"\n {'number of duplicate values'.title()} :- {len(df.loc[df.duplicated()])}")

## Null values
print(f"{'null values'.title()} :- {df.isnull().values.any()}")

## information about dataset
print(f"{'dataset info'.title()}\n ")
df.info()
# Out:
# Shape Of The Dataset :- (100, 64)
#
#  Number Of Duplicate Values :- 0
# Null Values :- True
# Dataset Info
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 2 to 34
# Data columns (total 64 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    float64
#  3   Gross                   100 non-null    float64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
# ...

# %%
pd.set_option("display.max_rows", 64)

# %%
df.isnull().sum()
# Out:
# Title                      0
# title_year                 0
# budget                     0
# Gross                      0
# actor_1_name               0
# actor_2_name               0
# actor_3_name               0
# actor_1_facebook_likes     0
# actor_2_facebook_likes     1
# actor_3_facebook_likes     2
# IMDb_rating                0
# genre_1                    0
# genre_2                    3
# genre_3                   26
# MetaCritic                 5
# Runtime                    0
# CVotes10                   0
# CVotes09                   0
# CVotes08                   0
# CVotes07                   0
# CVotes06                   0
# CVotes05                   0
# CVotes04                   0
# CVotes03                   0
# CVotes02                   0
# CVotes01                   0
# CVotesMale                 0
# CVotesFemale               0
# CVotesU18                  0
# CVotesU18M                 0
# CVotesU18F                 0
# CVotes1829                 0
# ...

# %%
for column in df.columns:
    if df[column].dtypes==object:
        print(str(column)+':'+str(df[column].unique()))
        print(df[column].value_counts())
        print('************************************************************************************************************')
        print('\n')
# Out:
# Title:['La La Land' 'Zootopia' 'Lion' 'Arrival' 'Manchester by the Sea'
#  'Hell or High Water' 'Doctor Strange' 'Tangled' 'The Dark Knight Rises'
#  'Captain America: Civil War' 'The Hobbit: The Desolation of Smaug'
#  'The Avengers' 'Toy Story 3' 'Skyfall' 'X-Men: Days of Future Past'
#  'Star Trek Into Darkness' 'The Hobbit: An Unexpected Journey'
#  'Edge of Tomorrow' 'Inside Out' 'Guardians of the Galaxy'
#  'Captain America: The Winter Soldier' 'Dawn of the Planet of the Apes'
#  'Hugo' 'Big Hero 6' 'How to Train Your Dragon' 'Wreck-It Ralph'
#  'Interstellar' 'Inception' 'X-Men: First Class' 'Mad Max: Fury Road'
#  'How to Train Your Dragon 2' 'The Revenant'
#  'The Hunger Games: Catching Fire' 'The Martian' 'Gravity'
#  'Django Unchained' 'The Wolf of Wall Street'
#  'Rise of the Planet of the Apes' 'The Girl with the Dragon Tattoo'
#  'The Little Prince' 'Shutter Island' 'Despicable Me' 'Fury' 'Gone Girl'
#  'Les MisÃ©rables' 'The Lego Movie' 'Scott Pilgrim vs. the World'
# ...

# %%
df.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %%
df_cat=df.loc[:,df.dtypes==np.object]

# %%
df_cat.describe()
# Out:
#           Title       actor_1_name actor_2_name          actor_3_name genre_1  \
# count       100                100          100                   100     100
# unique      100                 75           94                    96       8
# top     Boyhood  Leonardo DiCaprio   Adam Brown  Joseph Gordon-Levitt  Action
# freq          1                  5            2                     2      27
#
#        genre_2 genre_3 content_rating Country
# count       97      74            100     100
# unique      19      15              4       6
# top      Drama  Sci-Fi          PG-13     USA
# freq        35      15             45      81

# %% [markdown]
# ## 2) Data Analysis

# %% [markdown]
# Subtask 1

# %%
df.iloc[:,2:4]=df.iloc[:,2:4]/1000000

# %% [markdown]
# Subtask 2

# %%
df['profit']=df['Gross']-df['budget']

# %%
df.head()
# Out:
#                    Title  title_year  budget       Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.101803      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268248  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.738905         Dev Patel
# 3                Arrival        2016    47.0  100.546139         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# ...

# %%
df.sort_values(by=['profit'], ascending=False,inplace=True)

# %%
top10=df.iloc[:10,:]

# %%
top10
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
# 8                        The Dark Knight Rises        2012   250.0
# 45                              The Lego Movie        2014    60.0
# 1                                     Zootopia        2016   150.0
# 41                               Despicable Me        2010    69.0
# 18                                  Inside Out        2015   175.0
#
#          Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225        Doug Walker         Rob Walker                      0
# ...

# %%
df.plot.scatter(x = 'budget', y = 'profit')
# Out:
# <AxesSubplot:xlabel='budget', ylabel='profit'>

# %%
sns.lineplot(x='budget', y='profit', data=df)
plt.show()

# %% [markdown]
# There is non-linear relationship between budget and profit and it doesn't imply significant causal relationship either because the profit is not solely dependent on budget and there may be some other important factors as well which might describe profit very well, but one thing is noticeable that the mean profit increases with increase in budget over a range (Peak values of profit increase with increase in budget whereas minimum value of profit(loss) has certain limit according to budget)

# %%
neg_profit= df[df['profit']<0]

# %%
neg_profit.head()
# Out:
#                       Title  title_year  budget      Gross      actor_1_name  \
# 99  Tucker and Dale vs Evil        2010     5.0   0.223838    Katrina Bowden
# 89                    Amour        2012     8.9   0.225377  Isabelle Huppert
# 56                     Rush        2013    38.0  26.903709   Chris Hemsworth
# 66                  Warrior        2011    25.0  13.651662         Tom Hardy
# 82                  Flipped        2010    14.0   1.752214  Madeline Carroll
#
#          actor_2_name            actor_3_name  actor_1_facebook_likes  \
# 99       Tyler Labine          Chelan Simmons                     948
# 89    Emmanuelle Riva  Jean-Louis Trintignant                     678
# 56       Olivia Wilde    Alexandra Maria Lara                   26000
# 66       Frank Grillo              Kevin Dunn                   27000
# 82  Rebecca De Mornay             Aidan Quinn                    1000
#
#     actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating genre_1  \
# ...

# %% [markdown]
# Subtask 3

# %%
df_t = df.iloc[:,7:10].sum(axis=1)

# %%
df['total_likes']=df_t

# %%
df.sort_values(by=['total_likes'], ascending=False,inplace=True)

# %%
l=df.iloc[:5,4:7]

# %%
list_=l.values.tolist()

# %%
list_
# Out:
# [['Dev Patel', 'Nicole Kidman', 'Rooney Mara'],
#  ['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Casey Affleck', 'Michelle Williams ', 'Kyle Chandler'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt']]

# %% [markdown]
# Subtask 4

# %%
dfbygenre=df[['genre_1','genre_2','genre_3','CVotes10','CVotes09','CVotes08','CVotes07','CVotes06','CVotes05','CVotes04','CVotes03','CVotes02','CVotes01','CVotesMale','CVotesFemale','CVotesU18','CVotesU18M','CVotesU18F','CVotes1829','CVotes1829M','CVotes1829F','CVotes3044','CVotes3044M','CVotes3044F','CVotes45A','CVotes45AM','CVotes45AF','CVotes1000','CVotesUS','CVotesnUS','VotesM','VotesF','VotesU18','VotesU18M','VotesU18F','Votes1829','Votes1829M','Votes1829F','Votes3044','Votes45A','Votes45AM','Votes45AF','Votes1000','VotesUS','VotesnUS']]

# %%
dfbygenre['cnt']=1

# %%
dfbyg1=dfbygenre.groupby(['genre_1'])['CVotes10','CVotes09','CVotes08','CVotes07','CVotes06','CVotes05','CVotes04','CVotes03','CVotes02','CVotes01','CVotesMale','CVotesFemale','CVotesU18','CVotesU18M','CVotesU18F','CVotes1829','CVotes1829M','CVotes1829F','CVotes3044','CVotes3044M','CVotes3044F','CVotes45A','CVotes45AM','CVotes45AF','CVotes1000','CVotesUS','CVotesnUS','VotesM','VotesF','VotesU18','VotesU18M','VotesU18F','Votes1829','Votes1829M','Votes1829F','Votes3044','Votes45A','Votes45AM','Votes45AF','Votes1000','VotesUS','VotesnUS','cnt'].apply(lambda x : x.sum())

# %%
dfbyg2=dfbygenre.groupby(['genre_2'])['CVotes10','CVotes09','CVotes08','CVotes07','CVotes06','CVotes05','CVotes04','CVotes03','CVotes02','CVotes01','CVotesMale','CVotesFemale','CVotesU18','CVotesU18M','CVotesU18F','CVotes1829','CVotes1829M','CVotes1829F','CVotes3044','CVotes3044M','CVotes3044F','CVotes45A','CVotes45AM','CVotes45AF','CVotes1000','CVotesUS','CVotesnUS','VotesM','VotesF','VotesU18','VotesU18M','VotesU18F','Votes1829','Votes1829M','Votes1829F','Votes3044','Votes45A','Votes45AM','Votes45AF','Votes1000','VotesUS','VotesnUS','cnt'].apply(lambda x : x.sum())

# %%
dfbyg3=dfbygenre.groupby(['genre_3'])['CVotes10','CVotes09','CVotes08','CVotes07','CVotes06','CVotes05','CVotes04','CVotes03','CVotes02','CVotes01','CVotesMale','CVotesFemale','CVotesU18','CVotesU18M','CVotesU18F','CVotes1829','CVotes1829M','CVotes1829F','CVotes3044','CVotes3044M','CVotes3044F','CVotes45A','CVotes45AM','CVotes45AF','CVotes1000','CVotesUS','CVotesnUS','VotesM','VotesF','VotesU18','VotesU18M','VotesU18F','Votes1829','Votes1829M','Votes1829F','Votes3044','Votes45A','Votes45AM','Votes45AF','Votes1000','VotesUS','VotesnUS','cnt'].apply(lambda x : x.sum())

# %%
dfadd2=dfbyg1.add(dfbyg2, fill_value=0)

# %%
dfadd=dfbyg2.add(dfbyg3, fill_value=0)

# %%
dfadd
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action      238060.0   285510.0   430062.0   260106.0    88580.0   29250.0
# Adventure  2535880.0  2834374.0  3701787.0  2315706.0   846589.0  301985.0
# Biography   185172.0   313178.0   576374.0   370003.0   119348.0   38643.0
# Comedy     1012399.0  1278082.0  1736456.0  1072503.0   394853.0  144919.0
# Crime       191236.0   276897.0   336026.0   193797.0    71635.0   27230.0
# Drama      2323713.0  3441322.0  5279690.0  3240734.0  1112151.0  388438.0
# Family       98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# Fantasy     572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# History     151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# Horror       16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# Music       184649.0   233055.0   197296.0    94838.0    33954.0   14075.0
# ...

# %%
genretop10= dfadd[dfadd['cnt']>=10]

# %%
genretop10=genretop10.div(genretop10.cnt, axis=0)

# %%
genretop10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Adventure   97533.846154  109014.384615  142376.423077   89065.615385
# Comedy      72314.214286   91291.571429  124032.571429   76607.357143
# Drama       49440.702128   73219.617021  112333.829787   68951.787234
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Adventure  32561.115385  11614.807692  4788.884615  2697.846154  1835.346154
# Comedy     28203.785714  10351.357143  4405.785714  2518.071429  1721.785714
# Drama      23662.787234   8264.638298  3403.191489  1899.574468  1321.638298
# Romance    21637.615385   8530.846154  3762.538462  2130.615385  1476.923077
# Sci-Fi     39518.294118  14951.470588  6583.823529  3876.705882  2715.941176
# ...

# %%
genretop10.iloc[:,:27] = genretop10.iloc[:,:27].astype(int)

# %%
genretop10=genretop10.apply(lambda x : [int(i) if i % 1 == 0 else round(i,2) for i in x])

# %% [markdown]
# Subtask 5

# %%
genretop10.sort_values(by=['CVotes1000'], ascending=False,inplace=True)

# %%
genretop10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
# Adventure     97533    109014    142376     89065     32561     11614
# Comedy        72314     91291    124032     76607     28203     10351
# Drama         49440     73219    112333     68951     23662      8264
# Romance       42304     53037     82252     54833     21637      8530
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Sci-Fi         6583      3876      2715      6731      422437         83618
# Thriller       5021      2918      1982      4433      333785         68749
# Adventure      4788      2697      1835      4836      316336         73192
# Comedy         4405      2518      1721      3937      260682         69353
# Drama          3403      1899      1321      2975      229265         51232
# ...

# %%
sns.barplot(x = genretop10.index, y ='CVotes1000',data = genretop10)
plt.show()
